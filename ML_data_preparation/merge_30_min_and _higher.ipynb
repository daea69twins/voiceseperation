# %%
"""
Alexander Brown
1/26/2022

We want to concatenate all of the audio clips for each person, 
and keep the results that fit our length preferences.

https://www.robots.ox.ac.uk/~vgg/data/voxceleb/vox1.html
"""

import os
import soundfile as sf
import librosa
from pydub import AudioSegment

# %%
"""
determine the total length of .wav file duration available for each character
"""
# specify the parent directory containing all of the 'id' directories
# note that directory notation must use '/' rather than '\'
pc_specific_path = 'D:/ZaknafeinII/daea2022'
vox_dev_specific_path = '/vox1_dev_wav_partaa~/wav'
datafolder = pc_specific_path + vox_dev_specific_path

# this produces an iterable object containing all of the 'id' directories
character_ids = os.listdir(datafolder)

# this dict will store the total .wav file summed duration for each character
char_durations = {}

# iterate over each different character
for character_id in character_ids:
    
    summed_duration = 0
    
    curr_char_dir = datafolder+'/'+character_id

    # iterate over each audio directory belonging to that character
    for (dirpath, dirnames, filenames) in os.walk(curr_char_dir):
        
        # iterate over each .wav audio file in the audio directory
        for filename in filenames:
            filepath = dirpath+'/'+filename
            
            # add the file duration to the summed duration for the character
            summed_duration = summed_duration + librosa.get_duration(filename=filepath)
            char_durations[character_id] = summed_duration
            
    print('%s had a duration of %f seconds (%f minutes)' % (character_id, summed_duration, summed_duration/60))
# Out:
# id10004 had a duration of 969.526750 seconds (16.158779 minutes)
# id10009 had a duration of 443.883687 seconds (7.398061 minutes)
# id10011 had a duration of 983.327438 seconds (16.388791 minutes)
# id10016 had a duration of 2393.055813 seconds (39.884264 minutes)
# id10017 had a duration of 928.369500 seconds (15.472825 minutes)
# id10018 had a duration of 1828.496813 seconds (30.474947 minutes)
# id10019 had a duration of 534.484875 seconds (8.908081 minutes)
# id10020 had a duration of 4509.836813 seconds (75.163947 minutes)
# id10022 had a duration of 1212.613125 seconds (20.210219 minutes)
# id10027 had a duration of 766.885437 seconds (12.781424 minutes)
# id10030 had a duration of 675.925562 seconds (11.265426 minutes)
# id10032 had a duration of 998.845875 seconds (16.647431 minutes)
# id10035 had a duration of 984.888875 seconds (16.414815 minutes)
# id10036 had a duration of 1109.248438 seconds (18.487474 minutes)
# id10039 had a duration of 1211.885500 seconds (20.198092 minutes)
# id10041 had a duration of 1132.130500 seconds (18.868842 minutes)
# id10045 had a duration of 1928.058438 seconds (32.134307 minutes)
# id10047 had a duration of 1090.489437 seconds (18.174824 minutes)
# id10051 had a duration of 311.683125 seconds (5.194719 minutes)
# id10052 had a duration of 1736.452750 seconds (28.940879 minutes)
# id10053 had a duration of 1275.408875 seconds (21.256815 minutes)
# id10057 had a duration of 568.524063 seconds (9.475401 minutes)
# id10058 had a duration of 471.643750 seconds (7.860729 minutes)
# id10059 had a duration of 882.929500 seconds (14.715492 minutes)
# id10062 had a duration of 1373.730188 seconds (22.895503 minutes)
# id10066 had a duration of 807.886438 seconds (13.464774 minutes)
# id10071 had a duration of 1283.650437 seconds (21.394174 minutes)
# id10072 had a duration of 905.086875 seconds (15.084781 minutes)
# id10073 had a duration of 396.683438 seconds (6.611391 minutes)
# id10074 had a duration of 974.927000 seconds (16.248783 minutes)
# id10075 had a duration of 353.282875 seconds (5.888048 minutes)
# id10076 had a duration of 334.283312 seconds (5.571389 minutes)
# id10077 had a duration of 1080.607437 seconds (18.010124 minutes)
# id10079 had a duration of 757.126813 seconds (12.618780 minutes)
# id10080 had a duration of 1430.250313 seconds (23.837505 minutes)
# id10084 had a duration of 971.087000 seconds (16.184783 minutes)
# id10092 had a duration of 812.326937 seconds (13.538782 minutes)
# id10097 had a duration of 1575.290938 seconds (26.254849 minutes)
# id10099 had a duration of 357.043688 seconds (5.950728 minutes)
# id10104 had a duration of 2339.578563 seconds (38.992976 minutes)
# id10106 had a duration of 753.245688 seconds (12.554095 minutes)
# id10107 had a duration of 2048.778125 seconds (34.146302 minutes)
# id10113 had a duration of 1449.492313 seconds (24.158205 minutes)
# id10115 had a duration of 611.245750 seconds (10.187429 minutes)
# id10118 had a duration of 870.405375 seconds (14.506756 minutes)
# id10119 had a duration of 355.843125 seconds (5.930719 minutes)
# id10121 had a duration of 1673.249500 seconds (27.887492 minutes)
# id10122 had a duration of 424.723938 seconds (7.078732 minutes)
# id10125 had a duration of 1279.448875 seconds (21.324148 minutes)
# id10126 had a duration of 312.123187 seconds (5.202053 minutes)
# id10130 had a duration of 1896.215188 seconds (31.603586 minutes)
# id10135 had a duration of 723.725938 seconds (12.062099 minutes)
# id10144 had a duration of 1172.688500 seconds (19.544808 minutes)
# id10148 had a duration of 1987.137688 seconds (33.118961 minutes)
# id10149 had a duration of 581.484312 seconds (9.691405 minutes)
# id10150 had a duration of 375.003438 seconds (6.250057 minutes)
# id10151 had a duration of 1261.888750 seconds (21.031479 minutes)
# id10156 had a duration of 440.323125 seconds (7.338719 minutes)
# id10157 had a duration of 842.847813 seconds (14.047464 minutes)
# id10158 had a duration of 1022.167750 seconds (17.036129 minutes)
# id10159 had a duration of 688.525500 seconds (11.475425 minutes)
# id10165 had a duration of 631.645500 seconds (10.527425 minutes)
# id10166 had a duration of 637.286250 seconds (10.621437 minutes)
# id10168 had a duration of 2639.939813 seconds (43.998997 minutes)
# id10173 had a duration of 570.804125 seconds (9.513402 minutes)
# id10175 had a duration of 653.606188 seconds (10.893436 minutes)
# id10176 had a duration of 932.247125 seconds (15.537452 minutes)
# id10179 had a duration of 392.323187 seconds (6.538720 minutes)
# id10182 had a duration of 889.326875 seconds (14.822115 minutes)
# id10189 had a duration of 422.082812 seconds (7.034714 minutes)
# id10190 had a duration of 845.206688 seconds (14.086778 minutes)
# id10195 had a duration of 604.484125 seconds (10.074735 minutes)
# id10196 had a duration of 689.405125 seconds (11.490085 minutes)
# id10204 had a duration of 850.966125 seconds (14.182769 minutes)
# id10209 had a duration of 1600.851813 seconds (26.680864 minutes)
# id10216 had a duration of 1360.849750 seconds (22.680829 minutes)
# id10217 had a duration of 344.203250 seconds (5.736721 minutes)
# id10219 had a duration of 1064.288750 seconds (17.738146 minutes)
# id10222 had a duration of 916.926437 seconds (15.282107 minutes)
# id10224 had a duration of 1300.728500 seconds (21.678808 minutes)
# id10226 had a duration of 779.845312 seconds (12.997422 minutes)
# id10227 had a duration of 1138.048375 seconds (18.967473 minutes)
# id10238 had a duration of 1165.766813 seconds (19.429447 minutes)
# id10239 had a duration of 707.325562 seconds (11.788759 minutes)
# id10460 had a duration of 1184.047562 seconds (19.734126 minutes)
# id10463 had a duration of 965.487750 seconds (16.091462 minutes)
# id10466 had a duration of 1279.929813 seconds (21.332164 minutes)
# id10468 had a duration of 354.643312 seconds (5.910722 minutes)
# id10473 had a duration of 1620.011625 seconds (27.000194 minutes)
# id10476 had a duration of 663.403563 seconds (11.056726 minutes)
# id10477 had a duration of 411.723500 seconds (6.862058 minutes)
# id10481 had a duration of 680.206688 seconds (11.336778 minutes)
# id10484 had a duration of 2014.573937 seconds (33.576232 minutes)
# id10485 had a duration of 656.126500 seconds (10.935442 minutes)
# id10486 had a duration of 1865.534000 seconds (31.092233 minutes)
# id10492 had a duration of 984.406750 seconds (16.406779 minutes)
# id10493 had a duration of 477.204250 seconds (7.953404 minutes)
# id10494 had a duration of 888.406813 seconds (14.806780 minutes)
# id10495 had a duration of 608.964188 seconds (10.149403 minutes)
# id10500 had a duration of 944.326563 seconds (15.738776 minutes)
# id10504 had a duration of 1124.609125 seconds (18.743485 minutes)
# id10506 had a duration of 400.763812 seconds (6.679397 minutes)
# id10509 had a duration of 300.762938 seconds (5.012716 minutes)
# id10510 had a duration of 874.047562 seconds (14.567459 minutes)
# id10512 had a duration of 1029.447750 seconds (17.157463 minutes)
# id10513 had a duration of 1503.490312 seconds (25.058172 minutes)
# id10525 had a duration of 2374.497812 seconds (39.574964 minutes)
# id10527 had a duration of 854.605813 seconds (14.243430 minutes)
# id10530 had a duration of 718.247437 seconds (11.970791 minutes)
# id10531 had a duration of 988.529687 seconds (16.475495 minutes)
# id10533 had a duration of 1637.887688 seconds (27.298128 minutes)
# id10534 had a duration of 991.526625 seconds (16.525444 minutes)
# id10535 had a duration of 2137.534125 seconds (35.625569 minutes)
# id10541 had a duration of 914.008313 seconds (15.233472 minutes)
# id10545 had a duration of 814.287437 seconds (13.571457 minutes)
# id10549 had a duration of 883.126500 seconds (14.718775 minutes)
# id10551 had a duration of 653.325875 seconds (10.888765 minutes)
# id10553 had a duration of 892.168812 seconds (14.869480 minutes)
# id10554 had a duration of 558.004375 seconds (9.300073 minutes)
# id10555 had a duration of 580.324000 seconds (9.672067 minutes)
# id10558 had a duration of 313.843250 seconds (5.230721 minutes)
# id10563 had a duration of 1175.288625 seconds (19.588144 minutes)
# id10566 had a duration of 1097.366125 seconds (18.289435 minutes)
# id10567 had a duration of 1014.686250 seconds (16.911438 minutes)
# id10568 had a duration of 736.045687 seconds (12.267428 minutes)
# id10570 had a duration of 1008.648375 seconds (16.810806 minutes)
# id10572 had a duration of 1158.528750 seconds (19.308813 minutes)
# id10574 had a duration of 796.685812 seconds (13.278097 minutes)
# id10577 had a duration of 436.322875 seconds (7.272048 minutes)
# id10578 had a duration of 1013.567687 seconds (16.892795 minutes)
# id10585 had a duration of 357.043000 seconds (5.950717 minutes)
# id10589 had a duration of 748.525312 seconds (12.475422 minutes)
# id10591 had a duration of 465.723687 seconds (7.762061 minutes)
# id10592 had a duration of 482.603563 seconds (8.043393 minutes)
# id10593 had a duration of 530.605062 seconds (8.843418 minutes)
# id10595 had a duration of 826.166375 seconds (13.769440 minutes)
# id10596 had a duration of 443.723375 seconds (7.395390 minutes)
# id10598 had a duration of 571.084187 seconds (9.518070 minutes)
# id10602 had a duration of 401.683250 seconds (6.694721 minutes)
# id10605 had a duration of 555.003875 seconds (9.250065 minutes)
# id10609 had a duration of 1053.568000 seconds (17.559467 minutes)
# id10611 had a duration of 1170.289250 seconds (19.504821 minutes)
# id10612 had a duration of 514.044188 seconds (8.567403 minutes)
# id10615 had a duration of 1237.449813 seconds (20.624164 minutes)
# id10619 had a duration of 502.883750 seconds (8.381396 minutes)
# id10621 had a duration of 328.523188 seconds (5.475386 minutes)
# id10627 had a duration of 742.927375 seconds (12.382123 minutes)
# id10628 had a duration of 593.484187 seconds (9.891403 minutes)
# id10631 had a duration of 1599.652312 seconds (26.660872 minutes)
# id10634 had a duration of 1098.048125 seconds (18.300802 minutes)
# id10636 had a duration of 1450.972375 seconds (24.182873 minutes)
# id10639 had a duration of 563.044375 seconds (9.384073 minutes)
# id10640 had a duration of 424.563688 seconds (7.076061 minutes)
# id10644 had a duration of 1138.048813 seconds (18.967480 minutes)
# id10645 had a duration of 837.326875 seconds (13.955448 minutes)
# id10647 had a duration of 671.085125 seconds (11.184752 minutes)
# id10656 had a duration of 1188.247813 seconds (19.804130 minutes)
# id10658 had a duration of 390.123937 seconds (6.502066 minutes)
# id10661 had a duration of 668.804313 seconds (11.146739 minutes)
# id10663 had a duration of 848.246062 seconds (14.137434 minutes)
# id10664 had a duration of 1381.650750 seconds (23.027513 minutes)
# id10666 had a duration of 688.047000 seconds (11.467450 minutes)
# id10672 had a duration of 1207.167750 seconds (20.119462 minutes)
# id10674 had a duration of 913.127063 seconds (15.218784 minutes)
# id10677 had a duration of 1365.607938 seconds (22.760132 minutes)
# id10680 had a duration of 418.043188 seconds (6.967386 minutes)
# id10684 had a duration of 288.242813 seconds (4.804047 minutes)
# id10685 had a duration of 460.084187 seconds (7.668070 minutes)
# id10687 had a duration of 1386.767250 seconds (23.112787 minutes)
# id10688 had a duration of 891.005063 seconds (14.850084 minutes)
# id10691 had a duration of 540.365125 seconds (9.006085 minutes)
# id10698 had a duration of 890.926063 seconds (14.848768 minutes)
# id10699 had a duration of 610.844437 seconds (10.180741 minutes)
# id10700 had a duration of 589.443875 seconds (9.824065 minutes)
# id10702 had a duration of 826.245688 seconds (13.770761 minutes)
# id10712 had a duration of 1534.374625 seconds (25.572910 minutes)
# id10713 had a duration of 470.404750 seconds (7.840079 minutes)
# id10715 had a duration of 3790.503375 seconds (63.175056 minutes)
# id10719 had a duration of 976.686375 seconds (16.278106 minutes)
# id10724 had a duration of 1306.287250 seconds (21.771454 minutes)
# id10726 had a duration of 1393.489625 seconds (23.224827 minutes)
# id10728 had a duration of 494.763187 seconds (8.246053 minutes)
# id10729 had a duration of 1752.650750 seconds (29.210846 minutes)
# id10735 had a duration of 675.686562 seconds (11.261443 minutes)
# id10736 had a duration of 621.925812 seconds (10.365430 minutes)
# id10742 had a duration of 690.484938 seconds (11.508082 minutes)
# id10743 had a duration of 1513.251937 seconds (25.220866 minutes)
# id10747 had a duration of 1267.491562 seconds (21.124859 minutes)
# id10750 had a duration of 741.805375 seconds (12.363423 minutes)
# id10752 had a duration of 783.246125 seconds (13.054102 minutes)
# id10756 had a duration of 2584.335250 seconds (43.072254 minutes)
# id10758 had a duration of 2067.334500 seconds (34.455575 minutes)
# id10774 had a duration of 440.804688 seconds (7.346745 minutes)
# id10778 had a duration of 492.724875 seconds (8.212081 minutes)
# id10780 had a duration of 411.443187 seconds (6.857386 minutes)
# id10783 had a duration of 1268.328625 seconds (21.138810 minutes)
# id10786 had a duration of 3121.664625 seconds (52.027744 minutes)
# id10795 had a duration of 688.925938 seconds (11.482099 minutes)
# id10798 had a duration of 545.444250 seconds (9.090737 minutes)
# id10800 had a duration of 1128.450000 seconds (18.807500 minutes)
# id10804 had a duration of 811.648125 seconds (13.527469 minutes)
# id10809 had a duration of 318.203500 seconds (5.303392 minutes)
# id10810 had a duration of 482.003937 seconds (8.033399 minutes)
# id10811 had a duration of 447.883375 seconds (7.464723 minutes)
# id10815 had a duration of 410.602938 seconds (6.843382 minutes)
# id10817 had a duration of 1481.931187 seconds (24.698853 minutes)
# id10820 had a duration of 1193.007063 seconds (19.883451 minutes)
# id10830 had a duration of 698.406313 seconds (11.640105 minutes)
# id10831 had a duration of 384.043750 seconds (6.400729 minutes)
# id10836 had a duration of 606.285000 seconds (10.104750 minutes)
# id10838 had a duration of 539.885000 seconds (8.998083 minutes)
# id10839 had a duration of 1682.250625 seconds (28.037510 minutes)
# id10840 had a duration of 1310.448938 seconds (21.840816 minutes)
# id10841 had a duration of 766.366000 seconds (12.772767 minutes)
# id10846 had a duration of 1670.610750 seconds (27.843512 minutes)
# id10847 had a duration of 742.966625 seconds (12.382777 minutes)
# id10854 had a duration of 1358.809375 seconds (22.646823 minutes)
# id10856 had a duration of 2113.734000 seconds (35.228900 minutes)
# id10858 had a duration of 812.006062 seconds (13.533434 minutes)
# id10862 had a duration of 992.006562 seconds (16.533443 minutes)
# id10872 had a duration of 544.964500 seconds (9.082742 minutes)
# id10873 had a duration of 1970.817625 seconds (32.846960 minutes)
# id10878 had a duration of 801.805562 seconds (13.363426 minutes)
# id10883 had a duration of 1483.092125 seconds (24.718202 minutes)
# id10884 had a duration of 563.803063 seconds (9.396718 minutes)
# id10898 had a duration of 718.725937 seconds (11.978766 minutes)
# id10903 had a duration of 378.763438 seconds (6.312724 minutes)
# id10908 had a duration of 845.926687 seconds (14.098778 minutes)
# id10916 had a duration of 480.084563 seconds (8.001409 minutes)
# id10918 had a duration of 2171.373875 seconds (36.189565 minutes)
# id10920 had a duration of 1159.568813 seconds (19.326147 minutes)
# id10921 had a duration of 2982.658000 seconds (49.710967 minutes)
# id10922 had a duration of 1084.968687 seconds (18.082811 minutes)
# id10929 had a duration of 2357.658563 seconds (39.294309 minutes)
# id10930 had a duration of 842.847250 seconds (14.047454 minutes)
# id10931 had a duration of 3226.737250 seconds (53.778954 minutes)
# id10936 had a duration of 560.723625 seconds (9.345394 minutes)
# id10942 had a duration of 903.244125 seconds (15.054069 minutes)
# id10950 had a duration of 409.843937 seconds (6.830732 minutes)
# id10955 had a duration of 1410.093813 seconds (23.501564 minutes)
# id10956 had a duration of 1705.375313 seconds (28.422922 minutes)
# id10959 had a duration of 1196.650250 seconds (19.944171 minutes)
# id10962 had a duration of 512.485000 seconds (8.541417 minutes)
# id10964 had a duration of 1215.008812 seconds (20.250147 minutes)
# id10969 had a duration of 677.684812 seconds (11.294747 minutes)
# id10970 had a duration of 800.487062 seconds (13.341451 minutes)
# id10971 had a duration of 848.046687 seconds (14.134111 minutes)
# id10983 had a duration of 1809.774625 seconds (30.162910 minutes)
# id10984 had a duration of 589.524438 seconds (9.825407 minutes)
# id10985 had a duration of 561.405625 seconds (9.356760 minutes)
# id10991 had a duration of 645.244937 seconds (10.754082 minutes)
# id10992 had a duration of 544.804500 seconds (9.080075 minutes)
# id10994 had a duration of 1228.610688 seconds (20.476845 minutes)
# id10996 had a duration of 2507.576750 seconds (41.792946 minutes)
# id10997 had a duration of 3013.057125 seconds (50.217619 minutes)
# id10998 had a duration of 446.523438 seconds (7.442057 minutes)
# id10999 had a duration of 703.005625 seconds (11.716760 minutes)
# id11004 had a duration of 1443.132563 seconds (24.052209 minutes)
# id11005 had a duration of 702.126000 seconds (11.702100 minutes)
# id11010 had a duration of 757.806938 seconds (12.630116 minutes)
# id11011 had a duration of 857.288250 seconds (14.288138 minutes)
# id11016 had a duration of 1298.769375 seconds (21.646156 minutes)
# id11017 had a duration of 805.646875 seconds (13.427448 minutes)
# id11018 had a duration of 548.844125 seconds (9.147402 minutes)
# id11019 had a duration of 453.123938 seconds (7.552066 minutes)
# id11022 had a duration of 1821.174875 seconds (30.352915 minutes)
# id11024 had a duration of 1106.687562 seconds (18.444793 minutes)
# id11027 had a duration of 2113.414438 seconds (35.223574 minutes)
# id11028 had a duration of 1134.770875 seconds (18.912848 minutes)
# id11030 had a duration of 807.166687 seconds (13.452778 minutes)
# id11036 had a duration of 568.405000 seconds (9.473417 minutes)
# id11042 had a duration of 943.646250 seconds (15.727437 minutes)
# id11045 had a duration of 2300.413062 seconds (38.340218 minutes)
# id11048 had a duration of 1739.051750 seconds (28.984196 minutes)
# id11051 had a duration of 787.324063 seconds (13.122068 minutes)
# id11052 had a duration of 780.565938 seconds (13.009432 minutes)
# id11053 had a duration of 838.286625 seconds (13.971444 minutes)
# id11055 had a duration of 448.484875 seconds (7.474748 minutes)
# id11056 had a duration of 771.685500 seconds (12.861425 minutes)
# id11057 had a duration of 837.487625 seconds (13.958127 minutes)
# id11059 had a duration of 536.484687 seconds (8.941411 minutes)
# id11062 had a duration of 676.285438 seconds (11.271424 minutes)
# id11064 had a duration of 519.963250 seconds (8.666054 minutes)
# id11066 had a duration of 684.365437 seconds (11.406091 minutes)
# id11067 had a duration of 1171.327063 seconds (19.522118 minutes)
# id11072 had a duration of 2426.295187 seconds (40.438253 minutes)
# id11078 had a duration of 619.684375 seconds (10.328073 minutes)
# id11083 had a duration of 1092.087063 seconds (18.201451 minutes)
# id11086 had a duration of 1183.649688 seconds (19.727495 minutes)
# id11088 had a duration of 3656.422688 seconds (60.940378 minutes)
# id11248 had a duration of 1659.572750 seconds (27.659546 minutes)
# id11250 had a duration of 775.245312 seconds (12.920755 minutes)
# id11251 had a duration of 546.643812 seconds (9.110730 minutes)

# %%
count_over_30_min = 0
record = 0
for key in char_durations:
    if char_durations.get(key) > 1800:
        count_over_30_min = count_over_30_min + 1
        
        if char_durations.get(key) > record:
            record = char_durations.get(key)
        
print('%i/%i characters are over 30 minutes in duration' % (count_over_30_min, len(char_durations)))
print('the longest summed duration is %i minutes' % (record/60))
# Out:
# 45/395 characters are over 30 minutes in duration
# the longest summed duration is 4509

# %%
"""
sandbox to test combining .wav files

uses two specific .wav files from vox dev A

since we can use Python's sum() function to find the sum of a list, we should be able to
append all the .wav files to a list and then combine them
"""

# this block successfully combines two specified audio files
# https://stackoverflow.com/questions/2890703/how-to-join-two-wav-files-using-python
if True:
    sound1_filepath = 'F:/ZaknafeinII_Backup_02-02-22/daea/personalWaves/Recording0002.wav'
    sound2_filepath = 'F:/ZaknafeinII_Backup_02-02-22/daea/personalWaves/Recording0003.wav'
    # sound2_filepath = datafolder + '/id10004/6WxS8rpNjmk/00002.wav'
    # sounds_comb_filepath = pc_specific_path + '/testCombination.wav'
    sounds_comb_filepath = 'F:/ZaknafeinII_Backup_02-02-22/daea/personalWaves/ABrown_merged.wav'

    sound1 = AudioSegment.from_wav(sound1_filepath)
    sound2 = AudioSegment.from_wav(sound2_filepath)

    # sounds_comb = sound1 + sound2
    sounds_comb = sum([sound1, sound2])
    sounds_comb.export(sounds_comb_filepath, format='wav')

    sound1_dur = librosa.get_duration(filename=sound1_filepath)
    sound2_dur = librosa.get_duration(filename=sound2_filepath)
    sounds_comb_dur = librosa.get_duration(filename=sounds_comb_filepath)

    print('sound1 duration is %f seconds\nsound2 duration is %f seconds\nthe combined file duration is %f seconds' %
         (sound1_dur, sound2_dur, sounds_comb_dur))
# Out:
# sound1 duration is 3635.140000 seconds
# sound2 duration is 1976.280000 seconds
# the combined file duration is 5611.420000 seconds

# %%
"""
for each character with a length over 30 minutes (1800 seconds),
concatenate the .wav files to form a single, large .wav file

place all the merged .wav files in a parallel directory with names
corresponding to the character id
"""

# make the directory where the results will be stored
result_dir = 'mergedWaves'
os.mkdir(pc_specific_path + '/' + result_dir)

# iterate over each different character
for character_id in character_ids:
        
    # if the current character does not have audio files of duration >= 30 minutes, move on
    if char_durations.get(character_id) < 1800:
        continue
        
    curr_char_dir = datafolder+'/'+character_id
    
    # this tracks all the .wav files that need to be merged (all the .wav files belonging to the character)
    curr_char_wav_list = []

    # iterate over each audio directory belonging to that character
    for (dirpath, dirnames, filenames) in os.walk(curr_char_dir):
        
        # iterate over each .wav audio file in the audio directory
        for filename in filenames:
            filepath = dirpath+'/'+filename
            
            # add the .wav file to curr_char_wav_list so it can be combined later
            curr_char_wav_list.append(AudioSegment.from_wav(filepath))
            
    # now that all the .wav files to be combined have been collected in curr_char_wav_list
    # we can merge them and save the result
    output_path = pc_specific_path + '/' + result_dir + '/' + character_id + '_merged.wav'
    sounds_comb = sum(curr_char_wav_list)
    sounds_comb.export(output_path, format='wav')
