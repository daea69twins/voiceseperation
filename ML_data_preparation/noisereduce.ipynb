# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0,'/content/drive/My Drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install noisereduce

# %%
import librosa
import noisereduce as nr
import soundfile as sf

# %%
audiofile, sr_rate = librosa.load('/content/drive/MyDrive/output2/prediction_wavs/i2p2e39_4v_670_wav1.wav') 


reduced_noise = nr.reduce_noise(y=audiofile, sr=sr_rate)

sf.write('/content/drive/MyDrive/output2/prediction_wavs/i2p2e39_4v_670_wav1nr.wav', reduced_noise, sr_rate)
