# %%
import soundfile as sf
from torch import hub

# %%
# model = hub.load('mpariente/asteroid', 'conv_tasnet', 'mpariente/ConvTasNet_WHAM!_sepclean')

# really good voice sep
# model = hub.load('JorisCos/asteroid', 'conv_tasnet', 'JorisCos/ConvTasNet_Libri2Mix_sepclean_8k')

model = hub.load('JorisCos/asteroid', 'conv_tasnet', 'JorisCos/ConvTasNet_Libri2Mix_sepnoisy_16k')


# mpariente/DPRNNTasNet(ks=16)_WHAM!_sepclean
# Out:
# Using cache found in C:\Users\ZaknafeinII/.cache\torch\hub\JorisCos_asteroid_master

# %%
model.separate("C:/Users/ZaknafeinII/Desktop/tmp/test2.wav", resample=True, force_overwrite=True)

# %%
# print(model)
print(type(model))
print(model.parameters)
# Out:
# <class 'asteroid.models.conv_tasnet.ConvTasNet'>
# <bound method Module.parameters of ConvTasNet(
#   (encoder): Encoder(
#     (filterbank): FreeFB()
#   )
#   (masker): TDConvNet(
#     (bottleneck): Sequential(
#       (0): GlobLN()
#       (1): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#     )
#     (TCN): ModuleList(
#       (0): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (1): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
# ...
