# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Apr  7 03:04:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
# install asteroid
# !git clone https://github.com/asteroid-team/asteroid
# %cd asteroid
# !pip install -e .
# !pip install asteroid

# !pip install pytorch-lightning
# Out:
# fatal: destination path 'asteroid' already exists and is not an empty directory.
# /content/asteroid
# Obtaining file:///content/asteroid
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: julius in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (0.2.6)
# Requirement already satisfied: pytorch-lightning<1.5.0,>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (1.4.9)
# Requirement already satisfied: asteroid-filterbanks>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (0.4.0)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (1.10.0+cu111)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (1.4.1)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (1.3.5)
# Requirement already satisfied: torch-stoi>=0.1.2 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (0.1.2)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (1.21.5)
# Requirement already satisfied: torch-optimizer<0.2.0,>=0.0.1a12 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (0.1.0)
# Requirement already satisfied: PyYAML>=5.0 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (6.0)
# Requirement already satisfied: pb-bss-eval>=0.0.2 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (0.0.2)
# Requirement already satisfied: torchaudio>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (0.10.0+cu111)
# Requirement already satisfied: huggingface-hub>=0.0.2 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (0.5.1)
# Requirement already satisfied: SoundFile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from asteroid==0.6.0.dev0) (0.10.3.post1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asteroid-filterbanks>=0.4.0->asteroid==0.6.0.dev0) (3.10.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (4.63.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (4.11.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->asteroid==0.6.0.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->asteroid==0.6.0.dev0) (2018.9)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid==0.6.0.dev0) (1.5.2)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid==0.6.0.dev0) (0.3.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid==0.6.0.dev0) (0.4.1)
# Requirement already satisfied: mir-eval in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid==0.6.0.dev0) (0.7)
# Requirement already satisfied: pesq in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid==0.6.0.dev0) (0.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.4->asteroid==0.6.0.dev0) (1.15.0)
# Requirement already satisfied: pyDeprecate==0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.3.1)
# Requirement already satisfied: torchmetrics>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.7.3)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.18.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (2.8.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (2022.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (3.8.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from SoundFile>=0.10.2->asteroid==0.6.0.dev0) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->SoundFile>=0.10.2->asteroid==0.6.0.dev0) (2.21)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (3.3.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (3.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.44.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.0.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.35.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid==0.6.0.dev0) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (3.2.0)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer<0.2.0,>=0.0.1a12->asteroid==0.6.0.dev0) (0.1.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (2.0.12)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid==0.6.0.dev0) (21.4.0)
# Installing collected packages: asteroid
#   Attempting uninstall: asteroid
#     Found existing installation: asteroid 0.5.2
#     Uninstalling asteroid-0.5.2:
#       Successfully uninstalled asteroid-0.5.2
#   Running setup.py develop for asteroid
# Successfully installed asteroid
# Collecting asteroid
#   Using cached asteroid-0.5.2-py3-none-any.whl (246 kB)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from asteroid) (1.4.1)
# Requirement already satisfied: PyYAML>=5.0 in /usr/local/lib/python3.7/dist-packages (from asteroid) (6.0)
# Requirement already satisfied: julius in /usr/local/lib/python3.7/dist-packages (from asteroid) (0.2.6)
# Requirement already satisfied: torchaudio>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from asteroid) (0.10.0+cu111)
# Requirement already satisfied: asteroid-filterbanks>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from asteroid) (0.4.0)
# Requirement already satisfied: torch-optimizer<0.2.0,>=0.0.1a12 in /usr/local/lib/python3.7/dist-packages (from asteroid) (0.1.0)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.7/dist-packages (from asteroid) (1.3.5)
# Requirement already satisfied: SoundFile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from asteroid) (0.10.3.post1)
# Requirement already satisfied: huggingface-hub>=0.0.2 in /usr/local/lib/python3.7/dist-packages (from asteroid) (0.5.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from asteroid) (1.10.0+cu111)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.7/dist-packages (from asteroid) (1.21.5)
# Requirement already satisfied: pytorch-lightning<1.5.0,>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from asteroid) (1.4.9)
# Requirement already satisfied: pb-bss-eval>=0.0.2 in /usr/local/lib/python3.7/dist-packages (from asteroid) (0.0.2)
# Requirement already satisfied: torch-stoi>=0.1.2 in /usr/local/lib/python3.7/dist-packages (from asteroid) (0.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asteroid-filterbanks>=0.4.0->asteroid) (3.10.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid) (2.23.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid) (3.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.2->asteroid) (4.63.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.0.2->asteroid) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->asteroid) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->asteroid) (2018.9)
# Requirement already satisfied: mir-eval in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (0.7)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (1.5.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (0.4.1)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (0.3.3)
# Requirement already satisfied: pesq in /usr/local/lib/python3.7/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (0.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.4->asteroid) (1.15.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid) (2.8.0)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.18.2)
# Requirement already satisfied: pyDeprecate==0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.3.1)
# Requirement already satisfied: torchmetrics>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.7.3)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.5.0,>=1.0.1->asteroid) (2022.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (3.8.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from SoundFile>=0.10.2->asteroid) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->SoundFile>=0.10.2->asteroid) (2.21)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.37.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (3.17.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.44.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (57.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.0.2->asteroid) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (3.2.0)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer<0.2.0,>=0.0.1a12->asteroid) (0.1.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (2.0.12)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.3.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5.0,>=1.0.1->asteroid) (4.0.2)
# Installing collected packages: asteroid
# Successfully installed asteroid-0.5.2
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.7/dist-packages (1.4.9)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (3.10.0.2)
# Requirement already satisfied: pyDeprecate==0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (0.3.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.21.5)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (0.18.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (2.8.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.63.0)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.10.0+cu111)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (2022.3.0)
# Requirement already satisfied: torchmetrics>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (0.7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.23.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning) (3.0.7)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (3.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.35.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.37.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (57.4.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (3.3.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning) (3.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (21.4.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.7.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.0.12)

# %%
import torch
from torch import optim
from pytorch_lightning import Trainer
from asteroid.models import ConvTasNet
from asteroid.losses import pairwise_neg_sisdr, PITLossWrapper
from asteroid.data import LibriMix
from asteroid.engine import System
from torch.utils.data import DataLoader

# to enable cuda, you have to do a manual toggle in the settings
# menu 'runtime->change runtime->hardware accelerator->gpu'
torch.cuda.is_available()
# Out:
# True

# %%
# import custom data set from py in google drive
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0,'/content/drive/My Drive')
from custom_dataset_sandbox_index0 import CustomMixture 
from ConvTasNet_index0 import ConvTasNet_index0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_path = '/content/drive/MyDrive/output/'
# %cd /content/drive/MyDrive/output/
train_loader = DataLoader(CustomMixture(csv_path, "truetrain_metadata.csv"), num_workers=8, batch_size=2)
val_loader = DataLoader(CustomMixture(csv_path, "trueval_metadata.csv"), num_workers=8, batch_size=2)
# Out:
# /content/drive/MyDrive/output
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model = ConvTasNet_index0(n_src=2)

# PITLossWrapper works with any loss function.
loss = PITLossWrapper(pairwise_neg_sisdr, pit_from="pw_pt")

optimizer = optim.Adam(model.parameters(), lr=1e-3)

system = System(model, optimizer, loss, train_loader, val_loader)

# %%
trainer = Trainer(max_epochs=20, gpus=1, auto_select_gpus=True, log_every_n_steps=1)
trainer.fit(system)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type              | Params
# ------------------------------------------------
# 0 | model     | ConvTasNet_index0 | 5.1 M
# 1 | loss_func | PITLossWrapper    | 0
# ------------------------------------------------
# 5.1 M     Trainable params
# 0         Non-trainable params
# 5.1 M     Total params
# 20.202    Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6af72865ecb9> in <module>()
#       1 trainer = Trainer(max_epochs=20, gpus=1, auto_select_gpus=True, log_every_n_steps=1)
# ----> 2 trainer.fit(system)
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, train_dataloader)
#     550         self.checkpoint_connector.resume_start()
#     551
# --> 552         self._run(model)
#     553
#     554         assert self.state.stopped
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py in _run(self, model)
#     920
#     921         # dispatch `start_training` or `start_evaluating` or `start_predicting`
# --> 922         self._dispatch()
#     923
#     924         # plugin will finalized fitting (e.g. ddp_spawn will load trained model)
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py in _dispatch(self)
#     988             self.accelerator.start_predicting(self)
#     989         else:
# --> 990             self.accelerator.start_training(self)
#     991
#     992     def run_stage(self):
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/accelerators/accelerator.py in start_training(self, trainer)
#      90
#      91     def start_training(self, trainer: "pl.Trainer") -> None:
# ---> 92         self.training_type_plugin.start_training(trainer)
#      93
#      94     def start_evaluating(self, trainer: "pl.Trainer") -> None:
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py in start_training(self, trainer)
#     159     def start_training(self, trainer: "pl.Trainer") -> None:
#     160         # double dispatch to initiate the training loop
# --> 161         self._results = trainer.run_stage()
#     162
#     163     def start_evaluating(self, trainer: "pl.Trainer") -> None:
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py in run_stage(self)
#     998         if self.predicting:
#     999             return self._run_predict()
# -> 1000         return self._run_train()
#    1001
#    1002     def _pre_training_routine(self):
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py in _run_train(self)
#    1033             self.progress_bar_callback.disable()
#    1034
# -> 1035         self._run_sanity_check(self.lightning_module)
#    1036
#    1037         # enable train mode
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py in _run_sanity_check(self, ref_model)
#    1120             # run eval step
#    1121             with torch.no_grad():
# -> 1122                 self._evaluation_loop.run()
#    1123
#    1124             self.on_sanity_check_end()
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/base.py in run(self, *args, **kwargs)
#     109             try:
#     110                 self.on_advance_start(*args, **kwargs)
# --> 111                 self.advance(*args, **kwargs)
#     112                 self.on_advance_end()
#     113                 self.iteration_count += 1
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/dataloader/evaluation_loop.py in advance(self, *args, **kwargs)
#     109
#     110         dl_outputs = self.epoch_loop.run(
# --> 111             dataloader_iter, self.current_dataloader_idx, dl_max_batches, self.num_dataloaders
#     112         )
#     113
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/base.py in run(self, *args, **kwargs)
#     109             try:
#     110                 self.on_advance_start(*args, **kwargs)
# --> 111                 self.advance(*args, **kwargs)
#     112                 self.on_advance_end()
#     113                 self.iteration_count += 1
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py in advance(self, dataloader_iter, dataloader_idx, dl_max_batches, num_dataloaders)
#     109         # lightning module methods
#     110         with self.trainer.profiler.profile("evaluation_step_and_end"):
# --> 111             output = self.evaluation_step(batch, batch_idx, dataloader_idx)
#     112             output = self.evaluation_step_end(output)
#     113
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py in evaluation_step(self, batch, batch_idx, dataloader_idx)
#     156             self.trainer.lightning_module._current_fx_name = "validation_step"
#     157             with self.trainer.profiler.profile("validation_step"):
# --> 158                 output = self.trainer.accelerator.validation_step(step_kwargs)
#     159
#     160         return output
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/accelerators/accelerator.py in validation_step(self, step_kwargs)
#     209         """
#     210         with self.precision_plugin.val_step_context(), self.training_type_plugin.val_step_context():
# --> 211             return self.training_type_plugin.validation_step(*step_kwargs.values())
#     212
#     213     def test_step(self, step_kwargs: Dict[str, Union[Any, int]]) -> Optional[STEP_OUTPUT]:
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py in validation_step(self, *args, **kwargs)
#     176
#     177     def validation_step(self, *args, **kwargs):
# --> 178         return self.model.validation_step(*args, **kwargs)
#     179
#     180     def test_step(self, *args, **kwargs):
#
# /content/asteroid/asteroid/engine/system.py in validation_step(self, batch, batch_nb)
#     128             batch_nb (int): The number of the batch in the epoch.
#     129         """
# --> 130         loss = self.common_step(batch, batch_nb, train=False)
#     131         self.log("val_loss", loss, on_epoch=True, prog_bar=True)
#     132
#
# /content/asteroid/asteroid/engine/system.py in common_step(self, batch, batch_nb, train)
#     100         inputs, targets = batch
#     101         est_targets = self(inputs)
# --> 102         loss = self.loss_func(est_targets, targets)
#     103         return loss
#     104
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/asteroid/asteroid/losses/pit_wrapper.py in forward(self, est_targets, targets, return_est, reduce_kwargs, **kwargs)
#     101         elif self.pit_from == "pw_pt":
#     102             # Compute pairwise losses with a for loop.
# --> 103             pw_losses = self.get_pw_losses(self.loss_func, est_targets, targets, **kwargs)
#     104         elif self.pit_from == "perm_avg":
#     105             # Cannot get pairwise losses from this type of loss.
#
# /content/asteroid/asteroid/losses/pit_wrapper.py in get_pw_losses(loss_func, est_targets, targets, **kwargs)
#     159         for est_idx, est_src in enumerate(est_targets.transpose(0, 1)):
#     160             for target_idx, target_src in enumerate(targets.transpose(0, 1)):
# --> 161                 pair_wise_losses[:, est_idx, target_idx] = loss_func(est_src, target_src, **kwargs)
#     162         return pair_wise_losses
#     163
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/asteroid/asteroid/losses/sdr.py in forward(self, est_targets, targets)
#      46         if targets.size() != est_targets.size() or targets.ndim != 3:
#      47             raise TypeError(
# ---> 48                 f"Inputs must be of shape [batch, n_src, time], got {targets.size()} and {est_targets.size()} instead"
#      49             )
#      50         assert targets.size() == est_targets.size()
#
# TypeError: Inputs must be of shape [batch, n_src, time], got torch.Size([2, 88200]) and torch.Size([2, 88200]) instead

# %%
# save model
model_path = '/content/drive/MyDrive/output/model_saves/iteration3_part1.pt'
torch.save(model.state_dict(), model_path)

# %%
# load model

# model1 = ConvTasNet_index0(n_src=2)
# model1.load_state_dict(torch.load(model_path))
# model1.eval()

# %%
# test with specific audio clips

# import librosa
# audiofile, sr_rate = librosa.load('/content/drive/MyDrive/output/mixture/mixtureclip16027.wav') 
# prediction = model1(torch.from_numpy(audiofile))
# prediction1 = prediction

# import soundfile as sf
# sf.write('/content/drive/MyDrive/output/3v_test_wav2.wav', prediction1.detach().numpy()[1], sr_rate)

# %%
#print(prediction.detach().numpy()[0].shape)

# %%
# import torch
# from google.colab import drive
# drive.mount('/content/drive')
# import sys
# sys.path.insert(0,'/content/drive/My Drive')
# torch.cuda.is_available()
# checkpoint = torch.load('/content/drive/MyDrive/output/lightning_logs/version_2/checkpoints/epoch=0-step=11467.ckpt')
# torch.cuda.is_available()

# #print(checkpoint.keys())
# model = ConvTasNet(n_src=2)
# # model.from_pretrained(ConvTasNet, checkpoint['state_dict'])
# model.load_state_dict(checkpoint['state_dict'])
